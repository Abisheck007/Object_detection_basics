# %%
import cv2 as cv
import numpy as np
img = cv.imread('/home/abisheck/Downloads/abi.jpeg')
cv.imshow('abi',img)
cv.waitKey(0)
# Out:
# ...
# -1

# %%
capture = cv.VideoCapture('/home/abisheck/Videos/clg.mp4')
def resizing(frame,scale=0.75):
    width=int(frame.shape[1]*scale)
    height=int(frame.shape[1]*scale)
    dimensions = (width,height)
    
    return cv.resize(frame,dimensions,interpolation=cv.INTER_AREA)
while True:
    isTrue,frame=capture.read()
    
    frame_resized=resizing(frame,scale=0.2)
    cv.imshow('video resized',frame_resized)
    if cv.waitKey(20) & 0xFF==ord('d'):
        break
capture.release()
cv.destroyAllWindows()

# %%
#image to a grayscale
img = cv.imread('/home/abisheck/Downloads/abi.jpeg')

gray=cv.cvtColor(img,cv.COLOR_BGR2GRAY)
cv.imshow('gray',gray)
cv.waitKey(0)
# Out:
# -1

# %%
#img to hsv
hsv=cv.cvtColor(img,cv.COLOR_BGR2HSV)
cv.imshow('gray',hsv)
cv.waitKey(0)
# Out:
# -1

# %%
#lets see how it looks in matplotlib
import matplotlib.pyplot as plt
plt.imshow(img)
plt.show()
